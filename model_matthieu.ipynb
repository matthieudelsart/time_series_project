# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from utils.preprocessing import preprocess_data

data_train = pd.read_csv('data/train.csv')
data_train = preprocess_data(data_train, add_filter_outliers=False)
data_train.drop(columns=['Month', 'Weekday', 'Day'], inplace=True)

# %%
data_train
# Out:
#                        id  valeur_NO2  valeur_CO  valeur_O3  valeur_PM10  \
# 0     2020-01-01 00:00:00        42.9      0.718       15.7         73.1
# 1     2020-01-01 01:00:00        33.6      0.587       10.1         74.8
# 2     2020-01-01 02:00:00        29.3        NaN        5.1         51.0
# 3     2020-01-01 03:00:00        30.5      0.246        7.2         27.7
# 4     2020-01-01 04:00:00        29.3      0.204        8.3         15.3
# ...                   ...         ...        ...        ...          ...
# 40986 2024-09-03 18:00:00         NaN      0.222       55.1         12.0
# 40987 2024-09-03 19:00:00         NaN      0.245       48.2         13.4
# 40988 2024-09-03 20:00:00         NaN      0.234       44.5         12.4
# 40989 2024-09-03 21:00:00         NaN      0.225       25.9         10.6
# 40990 2024-09-03 22:00:00         NaN      0.184       37.7          8.5
#
#        valeur_PM25  is_holiday  is_jour_ferie  precipitation  wind_speed  ...  \
# 0             64.4           1              0            0.0         1.5  ...
# 1             66.0           1              0            0.0         2.6  ...
# 2             44.9           1              0            0.0         1.9  ...
# 3             25.1           1              0            0.0         1.8  ...
# 4             13.6           1              0            0.0         2.2  ...
# ...            ...         ...            ...            ...         ...  ...
# 40986          5.3           0              0            0.0         1.2  ...
# 40987          7.0           0              0            0.0         1.7  ...
# 40988          7.1           0              0            0.0         2.0  ...
# 40989          5.4           0              0            0.0         1.4  ...
# 40990          4.6           0              0            0.0         2.0  ...
#
#        Year  is_weekend  DayOfYear  HourOfDay  DayOfYear_sin  DayOfYear_cos  \
# 0      2020           0          1          0       0.017213       0.999852
# 1      2020           0          1          1       0.017213       0.999852
# 2      2020           0          1          2       0.017213       0.999852
# 3      2020           0          1          3       0.017213       0.999852
# 4      2020           0          1          4       0.017213       0.999852
# ...     ...         ...        ...        ...            ...            ...
# 40986  2024           0        247         18      -0.895839      -0.444378
# 40987  2024           0        247         19      -0.895839      -0.444378
# 40988  2024           0        247         20      -0.895839      -0.444378
# 40989  2024           0        247         21      -0.895839      -0.444378
# 40990  2024           0        247         22      -0.895839      -0.444378
#
#        HourOfDay_sin  HourOfDay_cos  Weekday_sin  Weekday_cos
# 0           0.000000   1.000000e+00     0.974928    -0.222521
# 1           0.258819   9.659258e-01     0.974928    -0.222521
# 2           0.500000   8.660254e-01     0.974928    -0.222521
# 3           0.707107   7.071068e-01     0.974928    -0.222521
# 4           0.866025   5.000000e-01     0.974928    -0.222521
# ...              ...            ...          ...          ...
# 40986      -1.000000  -1.836970e-16     0.781831     0.623490
# 40987      -0.965926   2.588190e-01     0.781831     0.623490
# 40988      -0.866025   5.000000e-01     0.781831     0.623490
# 40989      -0.707107   7.071068e-01     0.781831     0.623490
# 40990      -0.500000   8.660254e-01     0.781831     0.623490
#
# [40991 rows x 25 columns]

# %%
data_train.to_csv('data/train_preprocessed.csv', index=False)
